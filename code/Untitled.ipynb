# %%
run drive_rover.py
# Out:
# NOT recording this run ...
# (4033) wsgi starting up on http://0.0.0.0:4567
# (4033) accepted ('127.0.0.1', 55127)
# connect  8235eccff4bb4bd3939c51df2bc03b43
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.047492027282714844 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.07047200202941895 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.6697, 85.5888] throttle = 0.2 steer_angle = 7.9352 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.11336207389831543 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.6697, 85.5888] throttle = 0.2 steer_angle = 7.9352 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.14146709442138672 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0 position = [99.6691, 85.5885] throttle = 0.2 steer_angle = 7.8017 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.17131400108337402 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0111 position = [99.6688, 85.5884] throttle = 0.2 steer_angle = 7.7779 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.19870615005493164 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0402 position = [99.6669, 85.5875] throttle = 0.2 steer_angle = 7.7779 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.22571921348571777 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0251 position = [99.6653, 85.5867] throttle = 0.2 steer_angle = 7.8227 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.251359224319458 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0416 position = [99.6643, 85.5861] throttle = 0.2 steer_angle = 8.0041 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.2785930633544922 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.049 position = [99.6619, 85.5848] throttle = 0.2 steer_angle = 8.2138 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.311873197555542 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.049 position = [99.6619, 85.5848] throttle = 0.2 steer_angle = 8.2138 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.33495211601257324 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0459 position = [99.6596, 85.5836] throttle = 0.2 steer_angle = 8.492 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.35967516899108887 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0514 position = [99.6583, 85.5829] throttle = 0.2 steer_angle = 8.7114 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.3880281448364258 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0719 position = [99.6553, 85.5813] throttle = 0.2 steer_angle = 8.7114 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.4136660099029541 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0594 position = [99.6528, 85.5798] throttle = 0.2 steer_angle = 8.8068 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.4451432228088379 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0685 position = [99.6512, 85.579] throttle = 0.2 steer_angle = 9.0212 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.4777870178222656 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0685 position = [99.6512, 85.579] throttle = 0.2 steer_angle = 9.0212 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5017750263214111 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0774 position = [99.6473, 85.5769] throttle = 0.2 steer_angle = 9.2298 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5243270397186279 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0814 position = [99.6435, 85.5748] throttle = 0.2 steer_angle = 9.4604 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5469691753387451 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.085 position = [99.6416, 85.5738] throttle = 0.2 steer_angle = 9.4604 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5778141021728516 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0926 position = [99.6377, 85.5716] throttle = 0.2 steer_angle = 9.7832 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.612551212310791 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.0926 position = [99.6377, 85.5716] throttle = 0.2 steer_angle = 9.7832 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6415951251983643 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1103 position = [99.6334, 85.5692] throttle = 0.2 steer_angle = 9.6077 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6707720756530762 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1081 position = [99.6312, 85.568] throttle = 0.2 steer_angle = 9.87 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6999380588531494 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1011 position = [99.6277, 85.566] throttle = 0.2 steer_angle = 9.87 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7263121604919434 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1032 position = [99.6236, 85.5637] throttle = 0.2 steer_angle = 9.9086 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7511842250823975 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1252 position = [99.6212, 85.5623] throttle = 0.2 steer_angle = 10.1528 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7789192199707031 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1355 position = [99.6163, 85.5597] throttle = 0.2 steer_angle = 10.2668 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.8125030994415283 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1355 position = [99.6163, 85.5597] throttle = 0.2 steer_angle = 10.2668 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.8379571437835693 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1379 position = [99.6117, 85.5569] throttle = 0.2 steer_angle = 10.4469 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.862342119216919 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1372 position = [99.6092, 85.5555] throttle = 0.2 steer_angle = 10.3128 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.8850221633911133 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1365 position = [99.6043, 85.5525] throttle = 0.2 steer_angle = 10.3128 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9107911586761475 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1439 position = [99.5993, 85.5496] throttle = 0.2 steer_angle = 9.8935 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9453270435333252 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1439 position = [99.5993, 85.5496] throttle = 0.2 steer_angle = 9.8935 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9675760269165039 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1501 position = [99.5967, 85.548] throttle = 0.2 steer_angle = 10.1192 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.990638017654419 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1723 position = [99.5912, 85.5448] throttle = 0.2 steer_angle = 10.0647 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0127081871032715 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1751 position = [99.5853, 85.5414] throttle = 0.2 steer_angle = 10.0647 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0452501773834229 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1701 position = [99.5824, 85.5396] throttle = 0.2 steer_angle = 9.9141 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0777192115783691 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1701 position = [99.5824, 85.5396] throttle = 0.2 steer_angle = 9.9141 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0996119976043701 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1801 position = [99.5764, 85.536] throttle = 0.2 steer_angle = 9.98 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1225311756134033 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1676 position = [99.5709, 85.5328] throttle = 0.2 steer_angle = 9.2953 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1441881656646729 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1879 position = [99.5677, 85.5309] throttle = 0.2 steer_angle = 9.2953 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1786291599273682 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1863 position = [99.5614, 85.5271] throttle = 0.2 steer_angle = 9.864 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2117681503295898 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1863 position = [99.5614, 85.5271] throttle = 0.2 steer_angle = 9.864 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2337710857391357 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2071 position = [99.5542, 85.5228] throttle = 0.2 steer_angle = 9.5374 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2571442127227783 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.1972 position = [99.551, 85.5208] throttle = 0.2 steer_angle = 9.57 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2832081317901611 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.208 position = [99.5438, 85.5164] throttle = 0.2 steer_angle = 9.57 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3110032081604004 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.208 position = [99.537, 85.5124] throttle = 0.2 steer_angle = 9.4139 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3447411060333252 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.208 position = [99.537, 85.5124] throttle = 0.2 steer_angle = 9.4139 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3673510551452637 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2196 position = [99.5333, 85.5101] throttle = 0.2 steer_angle = 9.4084 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3899071216583252 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2264 position = [99.5253, 85.5054] throttle = 0.2 steer_angle = 9.2402 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4124841690063477 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2295 position = [99.5179, 85.5008] throttle = 0.2 steer_angle = 9.2402 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4453861713409424 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2264 position = [99.5141, 85.4985] throttle = 0.2 steer_angle = 9.185 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4779632091522217 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2264 position = [99.5141, 85.4985] throttle = 0.2 steer_angle = 9.185 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5043201446533203 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2335 position = [99.506, 85.4934] throttle = 0.2 steer_angle = 9.2441 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5280470848083496 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2407 position = [99.4983, 85.4886] throttle = 0.2 steer_angle = 9.0607 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.552584171295166 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2459 position = [99.4942, 85.486] throttle = 0.2 steer_angle = 9.0607 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5781002044677734 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2469 position = [99.4855, 85.4807] throttle = 0.2 steer_angle = 9.0419 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.610840082168579 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2469 position = [99.4855, 85.4807] throttle = 0.2 steer_angle = 9.0419 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6331942081451416 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2741 position = [99.4765, 85.475] throttle = 0.2 steer_angle = 9.1267 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.658182144165039 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2675 position = [99.472, 85.4721] throttle = 0.2 steer_angle = 9.0752 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6819920539855957 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2833 position = [99.4624, 85.4662] throttle = 0.2 steer_angle = 9.0752 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7124361991882324 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2799 position = [99.4534, 85.4604] throttle = 0.2 steer_angle = 9.089 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7442841529846191 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2799 position = [99.4534, 85.4604] throttle = 0.2 steer_angle = 9.089 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.767611026763916 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.277 position = [99.4489, 85.4575] throttle = 0.2 steer_angle = 8.9373 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7904021739959717 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2888 position = [99.4395, 85.4515] throttle = 0.2 steer_angle = 8.8297 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.8133080005645752 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2769 position = [99.4303, 85.4456] throttle = 0.2 steer_angle = 8.8297 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.845163106918335 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2956 position = [99.4254, 85.4424] throttle = 0.2 steer_angle = 8.6337 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.8778560161590576 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2956 position = [99.4254, 85.4424] throttle = 0.2 steer_angle = 8.6337 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.8996222019195557 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3072 position = [99.4152, 85.4357] throttle = 0.2 steer_angle = 8.6658 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9227001667022705 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2974 position = [99.4053, 85.4292] throttle = 0.2 steer_angle = 8.5642 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9485111236572266 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.2974 position = [99.4006, 85.4261] throttle = 0.2 steer_angle = 8.5642 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9792430400848389 samples remaining: 6 samples collected: 0
# Current FPS: 36
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3213 position = [99.39, 85.4193] throttle = 0.2 steer_angle = 8.5291 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.010974168777466 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3213 position = [99.39, 85.4193] throttle = 0.2 steer_angle = 8.5291 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.033698081970215 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3222 position = [99.3795, 85.4124] throttle = 0.2 steer_angle = 8.522 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.057502031326294 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3254 position = [99.3741, 85.4088] throttle = 0.2 steer_angle = 8.4385 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.0806801319122314 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3309 position = [99.3632, 85.4017] throttle = 0.2 steer_angle = 8.4385 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.1143290996551514 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3393 position = [99.3519, 85.3942] throttle = 0.2 steer_angle = 8.5495 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.1462039947509766 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3393 position = [99.3519, 85.3942] throttle = 0.2 steer_angle = 8.5495 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.17166805267334 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3461 position = [99.346, 85.3904] throttle = 0.2 steer_angle = 8.4948 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.195864200592041 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3493 position = [99.3342, 85.3826] throttle = 0.2 steer_angle = 8.3877 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2196221351623535 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3525 position = [99.3226, 85.3749] throttle = 0.2 steer_angle = 8.3877 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2439332008361816 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3688 position = [99.3164, 85.3707] throttle = 0.2 steer_angle = 8.5218 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2778360843658447 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3688 position = [99.3164, 85.3707] throttle = 0.2 steer_angle = 8.5218 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.3000171184539795 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3538 position = [99.3046, 85.3627] throttle = 0.2 steer_angle = 8.548 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.322042226791382 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3611 position = [99.293, 85.3549] throttle = 0.2 steer_angle = 8.2951 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.344372034072876 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3695 position = [99.2869, 85.3508] throttle = 0.2 steer_angle = 8.2951 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.3782641887664795 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3753 position = [99.2748, 85.3426] throttle = 0.2 steer_angle = 8.4607 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.4109461307525635 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3753 position = [99.2748, 85.3426] throttle = 0.2 steer_angle = 8.4607 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.4332311153411865 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3783 position = [99.2621, 85.334] throttle = 0.2 steer_angle = 8.3933 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.455808162689209 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3791 position = [99.2559, 85.3298] throttle = 0.2 steer_angle = 8.2719 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.477445125579834 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.373 position = [99.2436, 85.3212] throttle = 0.2 steer_angle = 8.2719 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.5131280422210693 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3898 position = [99.2307, 85.3123] throttle = 0.2 steer_angle = 8.2579 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.5443530082702637 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3898 position = [99.2307, 85.3123] throttle = 0.2 steer_angle = 8.2579 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.5664920806884766 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3888 position = [99.2244, 85.3079] throttle = 0.2 steer_angle = 8.2997 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.589736223220825 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.3998 position = [99.2116, 85.2991] throttle = 0.2 steer_angle = 8.2089 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.614504098892212 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4032 position = [99.1983, 85.2899] throttle = 0.2 steer_angle = 8.2089 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6439831256866455 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4042 position = [99.1917, 85.2853] throttle = 0.2 steer_angle = 8.3323 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6776041984558105 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4042 position = [99.1917, 85.2853] throttle = 0.2 steer_angle = 8.3323 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6997151374816895 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4179 position = [99.1778, 85.2757] throttle = 0.2 steer_angle = 8.3711 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.7219061851501465 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4244 position = [99.164, 85.2661] throttle = 0.2 steer_angle = 8.4938 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.744636058807373 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4172 position = [99.1572, 85.2613] throttle = 0.2 steer_angle = 8.4938 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.7784039974212646 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4273 position = [99.1434, 85.2516] throttle = 0.2 steer_angle = 8.5076 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8112761974334717 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4273 position = [99.1434, 85.2516] throttle = 0.2 steer_angle = 8.5076 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8368701934814453 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.438 position = [99.1293, 85.2416] throttle = 0.2 steer_angle = 8.4017 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8599941730499268 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4504 position = [99.1218, 85.2363] throttle = 0.2 steer_angle = 8.406 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8824431896209717 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4453 position = [99.1074, 85.2259] throttle = 0.2 steer_angle = 8.406 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9106051921844482 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4598 position = [99.0926, 85.2153] throttle = 0.2 steer_angle = 8.4518 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9447150230407715 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4598 position = [99.0926, 85.2153] throttle = 0.2 steer_angle = 8.4518 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9669740200042725 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4441 position = [99.0855, 85.2102] throttle = 0.2 steer_angle = 8.4586 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9897921085357666 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4571 position = [99.0706, 85.1995] throttle = 0.2 steer_angle = 8.4799 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.0118582248687744 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4655 position = [99.0555, 85.1884] throttle = 0.2 steer_angle = 8.4799 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.045016050338745 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4787 position = [99.0476, 85.1826] throttle = 0.2 steer_angle = 8.4381 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.0785951614379883 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4787 position = [99.0476, 85.1826] throttle = 0.2 steer_angle = 8.4381 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.1009180545806885 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4745 position = [99.0323, 85.1714] throttle = 0.2 steer_angle = 8.3706 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.123314142227173 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4787 position = [99.0171, 85.1601] throttle = 0.2 steer_angle = 8.3046 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.14520001411438 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.492 position = [99.0091, 85.1542] throttle = 0.2 steer_angle = 8.3046 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.178814172744751 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4936 position = [98.9932, 85.1424] throttle = 0.2 steer_angle = 8.5155 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.2117581367492676 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.4936 position = [98.9932, 85.1424] throttle = 0.2 steer_angle = 8.5155 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.2340362071990967 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# ...
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6028 position = [145.0734, 111.91] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.44234013557434 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6117 position = [145.0841, 111.9044] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.46868300437927 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6277 position = [145.1059, 111.8927] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.49502301216125 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6214 position = [145.1279, 111.8807] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.52930617332458 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6214 position = [145.1279, 111.8807] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.55096411705017 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6282 position = [145.1388, 111.8747] throttle = 0.2 steer_angle = -15.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.57294821739197 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6366 position = [145.1611, 111.8623] throttle = 0.2 steer_angle = -14.4509 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.59455513954163 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6351 position = [145.183, 111.8498] throttle = 0.2 steer_angle = -14.4509 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.62961721420288 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6569 position = [145.1945, 111.8433] throttle = 0.2 steer_angle = -12.773 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.66136407852173 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6569 position = [145.1945, 111.8433] throttle = 0.2 steer_angle = -12.773 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.68705201148987 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6416 position = [145.2168, 111.8306] throttle = 0.2 steer_angle = -12.8174 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.71033811569214 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6537 position = [145.2392, 111.8177] throttle = 0.2 steer_angle = -12.0321 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.73318600654602 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6647 position = [145.2507, 111.811] throttle = 0.2 steer_angle = -12.0321 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.76166105270386 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6626 position = [145.2732, 111.7976] throttle = 0.2 steer_angle = -11.8248 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.79674816131592 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6626 position = [145.2732, 111.7976] throttle = 0.2 steer_angle = -11.8248 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.8193871974945 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6719 position = [145.2963, 111.784] throttle = 0.2 steer_angle = -10.5064 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.8423900604248 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6684 position = [145.3078, 111.7773] throttle = 0.2 steer_angle = -10.408 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.8656451702118 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6783 position = [145.331, 111.7632] throttle = 0.2 steer_angle = -10.408 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.89664220809937 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6882 position = [145.3544, 111.7492] throttle = 0.2 steer_angle = -9.3657 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.92833018302917 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6882 position = [145.3544, 111.7492] throttle = 0.2 steer_angle = -9.3657 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.95112919807434 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6826 position = [145.366, 111.7422] throttle = 0.2 steer_angle = -8.9551 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.97391319274902 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6997 position = [145.39, 111.7277] throttle = 0.2 steer_angle = -8.5099 near_sample: 0 picking_up: 0 sending pickup: False total time: 200.99577522277832 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.6983 position = [145.4137, 111.7131] throttle = 0.2 steer_angle = -8.5099 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.02956414222717 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7017 position = [145.4256, 111.7057] throttle = 0.2 steer_angle = -8.6238 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.06128120422363 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7017 position = [145.4256, 111.7057] throttle = 0.2 steer_angle = -8.6238 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.08521914482117 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.719 position = [145.4503, 111.6905] throttle = 0.2 steer_angle = -7.2962 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.1107940673828 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7161 position = [145.4744, 111.6756] throttle = 0.2 steer_angle = -6.9013 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.1337251663208 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7149 position = [145.4865, 111.668] throttle = 0.2 steer_angle = -6.9013 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.1614830493927 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7231 position = [145.5113, 111.6525] throttle = 0.2 steer_angle = -6.2973 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.19532322883606 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7231 position = [145.5113, 111.6525] throttle = 0.2 steer_angle = -6.2973 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.21846914291382 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7292 position = [145.5362, 111.637] throttle = 0.2 steer_angle = -5.8621 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.24137616157532 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7273 position = [145.5485, 111.6293] throttle = 0.2 steer_angle = -6.1403 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.2639172077179 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7366 position = [145.5738, 111.6132] throttle = 0.2 steer_angle = -6.1403 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.29594612121582 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7477 position = [145.5992, 111.5973] throttle = 0.2 steer_angle = -4.7574 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.33006310462952 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7477 position = [145.5992, 111.5973] throttle = 0.2 steer_angle = -4.7574 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.35347509384155 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7442 position = [145.6118, 111.5893] throttle = 0.2 steer_angle = -5.3011 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.37658715248108 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7539 position = [145.6374, 111.5729] throttle = 0.2 steer_angle = -5.2334 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.39908409118652 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7608 position = [145.6629, 111.5565] throttle = 0.2 steer_angle = -5.2334 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.42890119552612 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7561 position = [145.6757, 111.5484] throttle = 0.2 steer_angle = -3.9309 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.4626350402832 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['samples_y', 'brake', 'image', 'steering_angle', 'pitch', 'picking_up', 'speed', 'throttle', 'near_sample', 'roll', 'samples_x', 'yaw', 'position', 'sample_count'])
# speed = 0.7561 position = [145.6757, 111.5484] throttle = 0.2 steer_angle = -3.9309 near_sample: 0 picking_up: 0 sending pickup: False total time: 201.4850800037384 samples remaining: 6 samples collected: 0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Uncomment the next line for use in a Jupyter notebook
#%matplotlib inline
import numpy as np
import cv2 as cv

# Define a function to perform a perspective transform
def perspect_transform(img, src, dst):
           
    M = cv.getPerspectiveTransform(src, dst)
    warped = cv.warpPerspective(img, M, (img.shape[1], img.shape[0]))# keep same size as input image
    
    return warped

def color_thresh(img, rgb_thresh=(160, 160, 160)):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:, :, 0] > rgb_thresh[0]) \
                & (img[:, :, 1] > rgb_thresh[1]) \
                & (img[:, :, 2] > rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    color_select[above_thresh] = 1
    # Return the binary image
    return color_select


# Read in the same sample image as before
img = mpimg.imread('../calibration_images/example_rock2.jpg')


dst_size = 5 
# Set a bottom offset to account for the fact that the bottom of the image 
# is not the position of the rover but a bit in front of it
# this is just a rough guess, feel free to change it!
bottom_offset = 6
src = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
dest = np.float32([[img.shape[1]/2 - dst_size, img.shape[0] - bottom_offset],
                  [img.shape[1]/2 + dst_size, img.shape[0] - bottom_offset],
                  [img.shape[1]/2 + dst_size, img.shape[0] - 2*dst_size - bottom_offset], 
                  [img.shape[1]/2 - dst_size, img.shape[0] - 2*dst_size - bottom_offset],
                                                  ])

# Assume you have already defined perspect_transform() and color_thresh()
warped = perspect_transform(img, src, dest)
colorsel = color_thresh(warped, rgb_thresh=(160, 160, 160))

# Plot the result
plt.imshow(colorsel, cmap='gray')
plt.show()
