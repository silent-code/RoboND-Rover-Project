# %%
run drive_rover.py
# Out:
# NOT recording this run ...
# (3381) wsgi starting up on http://0.0.0.0:4567
# (3381) accepted ('127.0.0.1', 54586)
# connect  581b5b4af9974659a006cddb6807bcb8
# Current FPS: 1
# dict_keys(['speed', 'picking_up', 'image', 'pitch', 'steering_angle', 'near_sample', 'samples_x', 'samples_y', 'brake', 'sample_count', 'position', 'roll', 'yaw', 'throttle'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['speed', 'picking_up', 'image', 'pitch', 'steering_angle', 'near_sample', 'samples_x', 'samples_y', 'brake', 'sample_count', 'position', 'roll', 'yaw', 'throttle'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.043515920639038086 samples remaining: 6 samples collected: 0
# Current FPS: 1
# ...
