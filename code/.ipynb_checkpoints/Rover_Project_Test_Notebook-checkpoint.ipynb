# %% [markdown]
# ## Rover Project Test Notebook
# This notebook contains the functions from the lesson and provides the scaffolding you need to test out your mapping methods.  The steps you need to complete in this notebook for the project are the following:
#
# * First just run each of the cells in the notebook, examine the code and the results of each.
# * Run the simulator in "Training Mode" and record some data. Note: the simulator may crash if you try to record a large (longer than a few minutes) dataset, but you don't need a ton of data, just some example images to work with.
# * Change the data directory path (2 cells below) to be the directory where you saved data
# * Test out the functions provided on your data
# * Write new functions (or modify existing ones) to report and map out detections of obstacles and rock samples (yellow rocks)
# * Populate the `process_image()` function with the appropriate steps/functions to go from a raw image to a worldmap.
# * Run the cell that calls `process_image()` using `moviepy` functions to create video output
# * Once you have mapping working, move on to modifying `perception.py` and `decision.py` to allow your rover to navigate and map in autonomous mode!
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# **Run the next cell to get code highlighting in the markdown cells.**

# %%
# %%HTML
# <style> code {background-color : orange !important;} </style>
# Out:
# <style> code {background-color : orange !important;} </style>

# %%
# %matplotlib inline
#%matplotlib qt # Choose %matplotlib qt to plot to an interactive window (note it may show up behind your browser)
# Make some of the relevant imports
import cv2 # OpenCV for perspective transform
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import scipy.misc # For saving images as needed
import glob  # For reading in a list of images from a folder
import imageio
imageio.plugins.ffmpeg.download()

# %% [markdown]
# ## Quick Look at the Data
# There's some example data provided in the `test_dataset` folder.  This basic dataset is enough to get you up and running but if you want to hone your methods more carefully you should record some data of your own to sample various scenarios in the simulator.
#
# Next, read in and display a random image from the `test_dataset` folder

# %%
path = '../test_dataset/IMG/*'
img_list = glob.glob(path)
# Grab a random image and display it
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
plt.imshow(image)

# %% [markdown]
# ## Calibration Data
# Read in and display example grid and rock sample calibration images.  You'll use the grid for perspective transform and the rock image for creating a new color selection that identifies these samples of interest.

# %%
# In the simulator you can toggle on a grid on the ground for calibration
# You can also toggle on the rock samples with the 0 (zero) key.  
# Here's an example of the grid and one of the rocks
example_grid = '../calibration_images/example_grid1.jpg'
example_rock = '../calibration_images/example_rock1.jpg'
grid_img = mpimg.imread(example_grid)
rock_img = mpimg.imread(example_rock)

fig = plt.figure(figsize=(12,3))
plt.subplot(121)
plt.imshow(grid_img)
plt.subplot(122)
plt.imshow(rock_img)

# %% [markdown]
# ## Perspective Transform
#
# Define the perspective transform function from the lesson and test it on an image.

# %%
# Define a function to perform a perspective transform
# I've used the example grid image above to choose source points for the
# grid cell in front of the rover (each grid cell is 1 square meter in the sim)
# Define a function to perform a perspective transform
def perspect_transform(img, src, dst):
           
    M = cv2.getPerspectiveTransform(src, dst)
    warped = cv2.warpPerspective(img, M, (img.shape[1], img.shape[0]))# keep same size as input image
    
    return warped


# Define calibration box in source (actual) and destination (desired) coordinates
# These source and destination points are defined to warp the image
# to a grid where each 10x10 pixel square represents 1 square meter
# The destination box will be 2*dst_size on each side
dst_size = 5 
# Set a bottom offset to account for the fact that the bottom of the image 
# is not the position of the rover but a bit in front of it
# this is just a rough guess, feel free to change it!
bottom_offset = 6
source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
destination = np.float32([[image.shape[1]/2 - dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - 2*dst_size - bottom_offset], 
                  [image.shape[1]/2 - dst_size, image.shape[0] - 2*dst_size - bottom_offset],
                  ])
warped = perspect_transform(grid_img, source, destination)
plt.imshow(warped)
#scipy.misc.imsave('../output/warped_example.jpg', warped)

# %% [markdown]
# ## Color Thresholding
# Define the color thresholding function from the lesson and apply it to the warped image
#
# **TODO:** Ultimately, you want your map to not just include navigable terrain but also obstacles and the positions of the rock samples you're searching for.  Modify this function or write a new function that returns the pixel locations of obstacles (areas below the threshold) and rock samples (yellow rocks in calibration images), such that you can map these areas into world coordinates as well.
# **Hints and Suggestion:**
# * For obstacles you can just invert your color selection that you used to detect ground pixels, i.e., if you've decided that everything above the threshold is navigable terrain, then everthing below the threshold must be an obstacle!
#
#
# * For rocks, think about imposing a lower and upper boundary in your color selection to be more specific about choosing colors.  You can investigate the colors of the rocks (the RGB pixel values) in an interactive matplotlib window to get a feel for the appropriate threshold range (keep in mind you may want different ranges for each of R, G and B!).  Feel free to get creative and even bring in functions from other libraries.  Here's an example of [color selection](http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html) using OpenCV.
#
# * **Beware However:** if you start manipulating images with OpenCV, keep in mind that it defaults to `BGR` instead of `RGB` color space when reading/writing images, so things can get confusing.

# %%
# Identify pixels above the threshold
# Threshold of RGB > 160 does a nice job of identifying ground pixels only
def color_thresh(img, rgb_thresh=(160, 160, 160)):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:,:,0] > rgb_thresh[0]) \
                & (img[:,:,1] > rgb_thresh[1]) \
                & (img[:,:,2] > rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    color_select[above_thresh] = 1
    # Return the binary image
    return color_select

threshed = color_thresh(warped)
plt.imshow(threshed, cmap='gray')
#scipy.misc.imsave('../output/warped_threshed.jpg', threshed*255)

# %% [markdown]
# ## Coordinate Transformations
# Define the functions used to do coordinate transforms and apply them to an image.

# %%
# Define a function to convert from image coords to rover coords
def rover_coords(binary_img):
    # Identify nonzero pixels
    ypos, xpos = binary_img.nonzero()
    # Calculate pixel positions with reference to the rover position being at the 
    # center bottom of the image.  
    x_pixel = -(ypos - binary_img.shape[0]).astype(np.float)
    y_pixel = -(xpos - binary_img.shape[1]/2 ).astype(np.float)
    return x_pixel, y_pixel

# Define a function to convert to radial coords in rover space
def to_polar_coords(x_pixel, y_pixel):
    # Convert (x_pixel, y_pixel) to (distance, angle) 
    # in polar coordinates in rover space
    # Calculate distance to each pixel
    dist = np.sqrt(x_pixel**2 + y_pixel**2)
    # Calculate angle away from vertical for each pixel
    angles = np.arctan2(y_pixel, x_pixel)
    return dist, angles

# Define a function to map rover space pixels to world space
def rotate_pix(xpix, ypix, yaw):
    # Convert yaw to radians
    yaw_rad = yaw * np.pi / 180
    xpix_rotated = (xpix * np.cos(yaw_rad)) - (ypix * np.sin(yaw_rad))
                            
    ypix_rotated = (xpix * np.sin(yaw_rad)) + (ypix * np.cos(yaw_rad))
    # Return the result  
    return xpix_rotated, ypix_rotated

def translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale): 
    # Apply a scaling and a translation
    xpix_translated = (xpix_rot / scale) + xpos
    ypix_translated = (ypix_rot / scale) + ypos
    # Return the result  
    return xpix_translated, ypix_translated


# Define a function to apply rotation and translation (and clipping)
# Once you define the two functions above this function should work
def pix_to_world(xpix, ypix, xpos, ypos, yaw, world_size, scale):
    # Apply rotation
    xpix_rot, ypix_rot = rotate_pix(xpix, ypix, yaw)
    # Apply translation
    xpix_tran, ypix_tran = translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale)
    # Perform rotation, translation and clipping all at once
    x_pix_world = np.clip(np.int_(xpix_tran), 0, world_size - 1)
    y_pix_world = np.clip(np.int_(ypix_tran), 0, world_size - 1)
    # Return the result
    return x_pix_world, y_pix_world

# Grab another random image
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
warped = perspect_transform(image, source, destination)
threshed = color_thresh(warped)

# Calculate pixel values in rover-centric coords and distance/angle to all pixels
xpix, ypix = rover_coords(threshed)
dist, angles = to_polar_coords(xpix, ypix)
mean_dir = np.mean(angles)

# Do some plotting
fig = plt.figure(figsize=(12,9))
plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(warped)
plt.subplot(223)
plt.imshow(threshed, cmap='gray')
plt.subplot(224)
plt.plot(xpix, ypix, '.')
plt.ylim(-160, 160)
plt.xlim(0, 160)
arrow_length = 100
x_arrow = arrow_length * np.cos(mean_dir)
y_arrow = arrow_length * np.sin(mean_dir)
plt.arrow(0, 0, x_arrow, y_arrow, color='red', zorder=2, head_width=10, width=2)

# %% [markdown]
# ## Read in saved data and ground truth map of the world
# The next cell is all setup to read your saved data into a `pandas` dataframe.  Here you'll also read in a "ground truth" map of the world, where white pixels (pixel value = 1) represent navigable terrain.
#
# After that, we'll define a class to store telemetry data and pathnames to images.  When you instantiate this class (`data = Databucket()`) you'll have a global variable called `data` that you can refer to for telemetry and map data within the `process_image()` function in the following cell.

# %%
# Import pandas and read in csv file as a dataframe
import pandas as pd
# Change the path below to your data directory
# If you are in a locale (e.g., Europe) that uses ',' as the decimal separator
# change the '.' to ','
df = pd.read_csv('../test_dataset/robot_log.csv', delimiter=';', decimal='.')
csv_img_list = df["Path"].tolist() # Create list of image pathnames
# Read in ground truth map and create a 3-channel image with it
ground_truth = mpimg.imread('../calibration_images/map_bw.png')
ground_truth_3d = np.dstack((ground_truth*0, ground_truth*255, ground_truth*0)).astype(np.float)

# Creating a class to be the data container
# Will read in saved data from csv file and populate this object
# Worldmap is instantiated as 200 x 200 grids corresponding 
# to a 200m x 200m space (same size as the ground truth map: 200 x 200 pixels)
# This encompasses the full range of output position values in x and y from the sim
class Databucket():
    def __init__(self):
        self.images = csv_img_list  
        self.xpos = df["X_Position"].values
        self.ypos = df["Y_Position"].values
        self.yaw = df["Yaw"].values
        self.count = 0 # This will be a running index
        self.worldmap = np.zeros((200, 200, 3)).astype(np.float)
        self.ground_truth = ground_truth_3d # Ground truth worldmap

# Instantiate a Databucket().. this will be a global variable/object
# that you can refer to in the process_image() function below
data = Databucket()

# %% [markdown]
# ## Write a function to process stored images
#
# Modify the `process_image()` function below by adding in the perception step processes (functions defined above) to perform image analysis and mapping.  The following cell is all set up to use this `process_image()` function in conjunction with the `moviepy` video processing package to create a video from the images you saved taking data in the simulator.
#
# In short, you will be passing individual images into `process_image()` and building up an image called `output_image` that will be stored as one frame of video.  You can make a mosaic of the various steps of your analysis process and add text as you like (example provided below).
#
#
#
# To start with, you can simply run the next three cells to see what happens, but then go ahead and modify them such that the output video demonstrates your mapping process.  Feel free to get creative!

# %%
def color_thresh_rock_sample(img, lower_yellow=[20,20,100], upper_yellow=[255,255,205]):
    # Convert BGR to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    # define range of blue color in HSV
    #lower_yellow = np.array([20,20,100])
    #upper_yellow = np.array([255,255,205])
    # Threshold the HSV image to get only yellow colors
    mask = cv2.inRange(hsv, lower_yellow, upper_yellow)
    binary_img = np.zeros_like(img[:,:,0])
    binary_img[mask > 0] = 1
    return binary_img

# Define a function to pass stored images to
# reading rover position and yaw angle from csv file
# This function will be used by moviepy to create an output video
def process_image(img):
    # Example of how to use the Databucket() object defined above
    # to print the current x, y and yaw values 
    # print(data.xpos[data.count], data.ypos[data.count], data.yaw[data.count])
    yaw = data.yaw[data.count]
    xpos = data.xpos[data.count]
    ypos = data.ypos[data.count]
    world_size = data.worldmap.shape[0]
    scale = 10
    dst_size = 5 
    # Set a bottom offset to account for the fact that the bottom of the image 
    # is not the position of the rover but a bit in front of it
    # this is just a rough guess, feel free to change it!
    bottom_offset = 6
    source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
    destination = np.float32([[img.shape[1]/2 - dst_size, img.shape[0] - bottom_offset],
                      [img.shape[1]/2 + dst_size, img.shape[0] - bottom_offset],
                      [img.shape[1]/2 + dst_size, img.shape[0] - 2*dst_size - bottom_offset], 
                      [img.shape[1]/2 - dst_size, img.shape[0] - 2*dst_size - bottom_offset],
                                                      ])
    # Apply perspective transform
    warped = perspect_transform(img, source, destination)
    
    # Apply color threshold to identify navigable terrain/obstacles/rock samples
    rgb_threshold = (160, 160, 160)
    navigable_terrain = color_thresh(warped, rgb_thresh=rgb_threshold)
    obstacle_terrain = 1 - navigable_terrain
    # define range of yellow color in RGB image
    lower_yellow = np.array([20, 20, 100])
    upper_yellow = np.array([255, 255, 205])
    rock_sample = color_thresh_rock_sample(warped, lower_yellow=lower_yellow, upper_yellow=upper_yellow)

   
    # Convert map image pixel values to rover-centric coords
    obstacle_x_rover, obstacle_y_rover = rover_coords(obstacle_terrain)
    rock_x_rover, rock_y_rover = rover_coords(rock_sample)
    navigable_x_rover, navigable_y_rover = rover_coords(navigable_terrain)
    
    # Convert rover-centric pixel values to world coordinates
    obstacle_x_world, obstacle_y_world = pix_to_world(obstacle_x_rover, obstacle_y_rover, xpos, ypos, yaw, world_size, scale)
    rock_x_world, rock_y_world = pix_to_world(rock_x_rover, rock_y_rover, xpos, ypos, yaw, world_size, scale)
    navigable_x_world, navigable_y_world = pix_to_world(navigable_x_rover, navigable_y_rover, xpos, ypos, yaw, world_size, scale)
    data.worldmap[obstacle_y_world, obstacle_x_world, 0] += 1
    data.worldmap[rock_y_world, rock_x_world, 1] += 1
    data.worldmap[navigable_y_world, navigable_x_world, 2] += 1
    
    # 7) Make a mosaic image, below is some example code
        # First create a blank image (can be whatever shape you like)
    output_image = np.zeros((img.shape[0] + data.worldmap.shape[0], img.shape[1]*2, 3))
        # Next you can populate regions of the image with various output
        # Here I'm putting the original image in the upper left hand corner
    output_image[0:img.shape[0], 0:img.shape[1]] = img

        # Let's create more images to add to the mosaic, first a warped image
    warped = perspect_transform(img, source, destination)
        # Add the warped image in the upper right hand corner
    output_image[0:img.shape[0], img.shape[1]:] = warped

        # Overlay worldmap with ground truth map
    map_add = cv2.addWeighted(data.worldmap, 1, data.ground_truth, 0.5, 0)
        # Flip map overlay so y-axis points upward and add to output_image 
    output_image[img.shape[0]:, 0:data.worldmap.shape[1]] = np.flipud(map_add)


        # Then putting some text over the image
    cv2.putText(output_image,"Test Data Run", (20, 20), 
                cv2.FONT_HERSHEY_COMPLEX, 0.4, (255, 255, 255), 1)
    if data.count < len(data.images) - 1:
        data.count += 1 # Keep track of the index in the Databucket()
    
    return output_image

# %% [markdown]
# ## Make a video from processed image data
# Use the [moviepy](https://zulko.github.io/moviepy/) library to process images and create a video.

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from moviepy.editor import ImageSequenceClip


# Define pathname to save the output video
output = '../output/test_mapping.mp4'
data = Databucket() # Re-initialize data in case you're running this cell multiple times
clip = ImageSequenceClip(data.images, fps=60) # Note: output video will be sped up because 
                                          # recording rate in simulator is fps=25
new_clip = clip.fl_image(process_image) #NOTE: this function expects color images!!
# %time new_clip.write_videofile(output, audio=False)
# Out:
# [MoviePy] >>>> Building video ../output/test_mapping.mp4
# [MoviePy] Writing video ../output/test_mapping.mp4
# 100%|██████████| 339/339 [00:03<00:00, 86.55it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../output/test_mapping.mp4
#
# CPU times: user 3.59 s, sys: 258 ms, total: 3.85 s
# Wall time: 4 s

# %% [markdown]
# ### This next cell should function as an inline video player
# If this fails to render the video, try running the following cell (alternative video rendering method).  You can also simply have a look at the saved mp4 in your `/output` folder

# %%
from IPython.display import HTML
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(output))
# Out:
# <video width="960" height="540" controls>
#   <source src="../output/test_mapping.mp4">
# </video>

# %% [markdown]
# ### Below is an alternative way to create a video in case the above cell did not work.

# %%
import io
import base64
video = io.open(output, 'r+b').read()
encoded_video = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded_video.decode('ascii')))

# %%
save output
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %%
csv_img_list
# Out:
# ['/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_17_704.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_17_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_17_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_17_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_17_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_18_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_432.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_19_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_20_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_21_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_22_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_164.jpg',
#  'Path',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_23_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_24_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_25_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_26_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_297.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_498.jpg',
#  'Path',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_27_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_830.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_28_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_764.jpg',
#  'Path',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_29_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_832.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_30_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_431.jpg',
#  'Path',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_31_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_32_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_33_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_032.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_165.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_34_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_297.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_35_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_36_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_032.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_37_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_38_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_39_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_40_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_830.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_41_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_230.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_297.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_497.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_42_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_43_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_032.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_099.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_44_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_45_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_46_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_897.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_47_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_48_965.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_49_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_032.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_50_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_51_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_52_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_630.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_09_53_964.jpg',
# ...
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_11_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_12_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_13_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_497.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_14_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_15_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_16_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_297.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_497.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_17_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_497.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_18_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_430.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_697.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_19_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_20_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_697.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_21_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_097.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_22_964.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_031.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_098.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_164.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_231.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_298.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_364.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_431.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_498.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_564.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_631.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_698.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_764.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_831.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_898.jpg',
#  '/Users/tz/RoboND-Rover-Project/test_dataset/IMG/robocam_2018_08_31_17_10_23_964.jpg']
