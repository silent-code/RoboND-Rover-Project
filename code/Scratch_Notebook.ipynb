# %%
run drive_rover.py
# Out:
# NOT recording this run ...
# connect  e76868465a744b7b96523a94238ff1ac
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0 samples remaining: 6 samples collected: 0
# (793) wsgi starting up on http://0.0.0.0:4567
# (793) accepted ('127.0.0.1', 50582)
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.03200984001159668 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.06082797050476074 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.6702, 85.5892] throttle = 0.2 steer_angle = 1.1785 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.09910297393798828 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.6704, 85.5893] throttle = 0.2 steer_angle = 1.1785 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.13028693199157715 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0 position = [99.6704, 85.5893] throttle = 0.2 steer_angle = 1.1785 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.15617585182189941 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0188 position = [99.6713, 85.59] throttle = 0.2 steer_angle = 1.1785 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.18108701705932617 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0294 position = [99.6723, 85.5909] throttle = 0.2 steer_angle = 1.3243 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.20503592491149902 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.022 position = [99.6728, 85.5913] throttle = 0.2 steer_angle = 1.3243 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.22937583923339844 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0223 position = [99.6739, 85.5922] throttle = 0.2 steer_angle = 1.3028 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.2645859718322754 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0412 position = [99.6757, 85.5936] throttle = 0.2 steer_angle = 1.0993 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.2971169948577881 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0412 position = [99.6757, 85.5936] throttle = 0.2 steer_angle = 1.0993 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.3230268955230713 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0594 position = [99.6771, 85.5947] throttle = 0.2 steer_angle = 1.0632 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.34678196907043457 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0325 position = [99.6787, 85.5961] throttle = 0.2 steer_angle = 1.2071 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.370074987411499 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0536 position = [99.6812, 85.5981] throttle = 0.2 steer_angle = 1.2071 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.3964409828186035 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0768 position = [99.683, 85.5995] throttle = 0.2 steer_angle = 1.076 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.43214988708496094 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0768 position = [99.683, 85.5995] throttle = 0.2 steer_angle = 1.076 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.4559650421142578 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0623 position = [99.6854, 85.6015] throttle = 0.2 steer_angle = 0.8968 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.47948789596557617 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0603 position = [99.6878, 85.6034] throttle = 0.2 steer_angle = 0.8458 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5065908432006836 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0613 position = [99.689, 85.6043] throttle = 0.2 steer_angle = 0.8458 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5332908630371094 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.083 position = [99.6925, 85.6071] throttle = 0.2 steer_angle = 0.6377 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5648870468139648 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1041 position = [99.6961, 85.6101] throttle = 0.2 steer_angle = 1.6912 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.5966508388519287 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1041 position = [99.6961, 85.6101] throttle = 0.2 steer_angle = 1.6912 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6202058792114258 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.092 position = [99.6977, 85.6114] throttle = 0.2 steer_angle = 1.6568 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6450908184051514 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.0998 position = [99.7013, 85.6143] throttle = 0.2 steer_angle = 1.7828 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6676409244537354 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1044 position = [99.7052, 85.6175] throttle = 0.2 steer_angle = 1.7828 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.6963260173797607 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1178 position = [99.7072, 85.6192] throttle = 0.2 steer_angle = 2.1007 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7304489612579346 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1178 position = [99.7072, 85.6192] throttle = 0.2 steer_angle = 2.1007 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.754572868347168 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1225 position = [99.7113, 85.6226] throttle = 0.2 steer_angle = 2.4668 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7770378589630127 samples remaining: 6 samples collected: 0
# Current FPS: None
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1238 position = [99.7154, 85.6259] throttle = 0.2 steer_angle = 2.5455 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.7987968921661377 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1302 position = [99.7175, 85.6277] throttle = 0.2 steer_angle = 2.5455 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.8304040431976318 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1297 position = [99.7219, 85.6314] throttle = 0.2 steer_angle = 2.7445 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.864495038986206 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1297 position = [99.7219, 85.6314] throttle = 0.2 steer_angle = 2.7445 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.8872108459472656 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1457 position = [99.7267, 85.6354] throttle = 0.2 steer_angle = 2.8446 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9110019207000732 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1483 position = [99.729, 85.6374] throttle = 0.2 steer_angle = 2.7249 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9359018802642822 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1425 position = [99.7336, 85.6412] throttle = 0.2 steer_angle = 2.7249 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9626548290252686 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1642 position = [99.7387, 85.6455] throttle = 0.2 steer_angle = 2.7612 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.9988110065460205 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1642 position = [99.7387, 85.6455] throttle = 0.2 steer_angle = 2.7612 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0215020179748535 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1571 position = [99.7411, 85.6474] throttle = 0.2 steer_angle = 2.8094 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0433828830718994 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1758 position = [99.746, 85.6517] throttle = 0.2 steer_angle = 2.7252 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0642459392547607 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1799 position = [99.7513, 85.6561] throttle = 0.2 steer_angle = 2.7252 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.0975358486175537 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1756 position = [99.754, 85.6583] throttle = 0.2 steer_angle = 2.7521 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1294009685516357 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1756 position = [99.754, 85.6583] throttle = 0.2 steer_angle = 2.7521 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1545369625091553 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1886 position = [99.7597, 85.6631] throttle = 0.2 steer_angle = 2.5887 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.177238941192627 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1748 position = [99.765, 85.6675] throttle = 0.2 steer_angle = 2.5845 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.1986899375915527 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1925 position = [99.7679, 85.6699] throttle = 0.2 steer_angle = 2.5845 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.231287956237793 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1911 position = [99.7739, 85.675] throttle = 0.2 steer_angle = 2.6761 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2635109424591064 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.1911 position = [99.7739, 85.675] throttle = 0.2 steer_angle = 2.6761 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.2848339080810547 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2096 position = [99.7801, 85.6803] throttle = 0.2 steer_angle = 2.8404 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3063218593597412 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2121 position = [99.7833, 85.683] throttle = 0.2 steer_angle = 2.7976 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.329401969909668 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2174 position = [99.7897, 85.6884] throttle = 0.2 steer_angle = 2.6182 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.363135814666748 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2174 position = [99.7897, 85.6884] throttle = 0.2 steer_angle = 2.6182 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.3862340450286865 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2112 position = [99.7963, 85.694] throttle = 0.2 steer_angle = 2.5498 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4082858562469482 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2318 position = [99.7999, 85.697] throttle = 0.2 steer_angle = 2.5021 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4289488792419434 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2331 position = [99.8067, 85.7028] throttle = 0.2 steer_angle = 2.5021 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4645719528198242 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2388 position = [99.8137, 85.7087] throttle = 0.2 steer_angle = 2.4971 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.4968149662017822 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2388 position = [99.8137, 85.7087] throttle = 0.2 steer_angle = 2.4971 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5183868408203125 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2439 position = [99.8174, 85.7118] throttle = 0.2 steer_angle = 2.5637 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.539402961730957 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2482 position = [99.8248, 85.7181] throttle = 0.2 steer_angle = 2.549 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5630710124969482 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2532 position = [99.8326, 85.7247] throttle = 0.2 steer_angle = 2.3358 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.5968239307403564 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2532 position = [99.8326, 85.7247] throttle = 0.2 steer_angle = 2.3358 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6209468841552734 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.258 position = [99.8365, 85.728] throttle = 0.2 steer_angle = 2.4155 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6432628631591797 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2658 position = [99.8445, 85.7347] throttle = 0.2 steer_angle = 2.2651 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6639289855957031 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2671 position = [99.8527, 85.7417] throttle = 0.2 steer_angle = 2.2651 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.6981279850006104 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2786 position = [99.857, 85.7452] throttle = 0.2 steer_angle = 2.2337 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7296078205108643 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2786 position = [99.857, 85.7452] throttle = 0.2 steer_angle = 2.2337 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7515869140625 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2831 position = [99.8651, 85.7521] throttle = 0.2 steer_angle = 2.2872 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7741270065307617 samples remaining: 6 samples collected: 0
# Current FPS: 31
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2849 position = [99.8738, 85.7594] throttle = 0.2 steer_angle = 2.2054 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.7971839904785156 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2863 position = [99.8782, 85.7631] throttle = 0.2 steer_angle = 2.2054 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.8304288387298584 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2759 position = [99.8867, 85.7703] throttle = 0.2 steer_angle = 2.2249 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.863318920135498 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2759 position = [99.8867, 85.7703] throttle = 0.2 steer_angle = 2.2249 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.8851189613342285 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.2979 position = [99.8957, 85.7779] throttle = 0.2 steer_angle = 2.3986 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9061708450317383 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3018 position = [99.9003, 85.7818] throttle = 0.2 steer_angle = 2.2525 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9294028282165527 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3094 position = [99.9094, 85.7895] throttle = 0.2 steer_angle = 2.2074 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9639599323272705 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3094 position = [99.9094, 85.7895] throttle = 0.2 steer_angle = 2.2074 near_sample: 0 picking_up: 0 sending pickup: False total time: 1.9885928630828857 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3261 position = [99.919, 85.7976] throttle = 0.2 steer_angle = 2.3527 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.01434588432312 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3163 position = [99.9238, 85.8016] throttle = 0.2 steer_angle = 2.2149 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.0373170375823975 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3287 position = [99.9339, 85.8101] throttle = 0.2 steer_angle = 2.2149 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.062877893447876 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3315 position = [99.9441, 85.8187] throttle = 0.2 steer_angle = 2.2967 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.0984349250793457 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3315 position = [99.9441, 85.8187] throttle = 0.2 steer_angle = 2.2967 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.121973991394043 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3281 position = [99.949, 85.8229] throttle = 0.2 steer_angle = 2.1926 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.143156051635742 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3324 position = [99.959, 85.8313] throttle = 0.2 steer_angle = 2.193 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.1641509532928467 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3419 position = [99.9696, 85.8401] throttle = 0.2 steer_angle = 2.193 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.198354959487915 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3292 position = [99.9744, 85.8441] throttle = 0.2 steer_angle = 2.277 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2299280166625977 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3292 position = [99.9744, 85.8441] throttle = 0.2 steer_angle = 2.277 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2542479038238525 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3648 position = [99.9856, 85.8536] throttle = 0.2 steer_angle = 2.5148 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.2812869548797607 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3668 position = [99.9969, 85.8631] throttle = 0.2 steer_angle = 2.3401 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.3053839206695557 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3575 position = [100.0023, 85.8677] throttle = 0.2 steer_angle = 2.3401 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.3293209075927734 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3669 position = [100.0138, 85.8774] throttle = 0.2 steer_angle = 2.3034 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.3643758296966553 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3669 position = [100.0138, 85.8774] throttle = 0.2 steer_angle = 2.3034 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.386133909225464 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3707 position = [100.0251, 85.8871] throttle = 0.2 steer_angle = 2.3773 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.4085428714752197 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3746 position = [100.0307, 85.8919] throttle = 0.2 steer_angle = 2.3443 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.430802822113037 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3804 position = [100.0421, 85.9016] throttle = 0.2 steer_angle = 2.3443 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.464416980743408 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3843 position = [100.0534, 85.9115] throttle = 0.2 steer_angle = 2.1368 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.49707293510437 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3843 position = [100.0534, 85.9115] throttle = 0.2 steer_angle = 2.1368 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.5204429626464844 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3822 position = [100.0591, 85.9164] throttle = 0.2 steer_angle = 2.0319 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.543026924133301 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.3931 position = [100.0712, 85.9268] throttle = 0.2 steer_angle = 2.0401 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.564764976501465 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4088 position = [100.0836, 85.9375] throttle = 0.2 steer_angle = 2.0401 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.597493886947632 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4071 position = [100.0898, 85.9428] throttle = 0.2 steer_angle = 1.9014 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6298320293426514 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4071 position = [100.0898, 85.9428] throttle = 0.2 steer_angle = 1.9014 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6532669067382812 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4142 position = [100.1021, 85.9535] throttle = 0.2 steer_angle = 1.9051 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.67590594291687 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4072 position = [100.1143, 85.9643] throttle = 0.2 steer_angle = 1.8736 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.6984009742736816 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4122 position = [100.1205, 85.9696] throttle = 0.2 steer_angle = 1.8736 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.7313108444213867 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4323 position = [100.1332, 85.9807] throttle = 0.2 steer_angle = 1.731 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.7638509273529053 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4323 position = [100.1332, 85.9807] throttle = 0.2 steer_angle = 1.731 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.7879278659820557 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4314 position = [100.146, 85.9919] throttle = 0.2 steer_angle = 1.6842 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8119640350341797 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4336 position = [100.1525, 85.9976] throttle = 0.2 steer_angle = 1.71 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.835479974746704 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4377 position = [100.1655, 86.0089] throttle = 0.2 steer_angle = 1.71 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8673908710479736 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4539 position = [100.179, 86.0206] throttle = 0.2 steer_angle = 1.861 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.8964478969573975 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4539 position = [100.179, 86.0206] throttle = 0.2 steer_angle = 1.861 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9209089279174805 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4496 position = [100.1858, 86.0265] throttle = 0.2 steer_angle = 2.0075 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9433629512786865 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4408 position = [100.1991, 86.038] throttle = 0.2 steer_angle = 2.1872 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.96555495262146 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4577 position = [100.2128, 86.05] throttle = 0.2 steer_angle = 2.1872 near_sample: 0 picking_up: 0 sending pickup: False total time: 2.9996559619903564 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4602 position = [100.2197, 86.056] throttle = 0.2 steer_angle = 2.0699 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.0297069549560547 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4602 position = [100.2197, 86.056] throttle = 0.2 steer_angle = 2.0699 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.054663896560669 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4612 position = [100.2334, 86.068] throttle = 0.2 steer_angle = 2.2623 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.0800418853759766 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4707 position = [100.2476, 86.0804] throttle = 0.2 steer_angle = 2.1629 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.1032779216766357 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4713 position = [100.2547, 86.0866] throttle = 0.2 steer_angle = 2.1629 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.129995822906494 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4934 position = [100.2696, 86.0997] throttle = 0.2 steer_angle = 2.3223 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.1644608974456787 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 0.4934 position = [100.2696, 86.0997] throttle = 0.2 steer_angle = 2.3223 near_sample: 0 picking_up: 0 sending pickup: False total time: 3.18733286857605 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# ...
# speed = 1.9955 position = [129.0217, 112.8976] throttle = 0.2 steer_angle = 13.892 near_sample: 0 picking_up: 0 sending pickup: False total time: 130.95532989501953 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9955 position = [129.0217, 112.8976] throttle = 0.2 steer_angle = 13.892 near_sample: 0 picking_up: 0 sending pickup: False total time: 130.97732400894165 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9978 position = [129.0931, 112.8625] throttle = 0.2 steer_angle = 13.1311 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.00091004371643 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9996 position = [129.1651, 112.8284] throttle = 0.2 steer_angle = 12.7566 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.02648901939392 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0012 position = [129.2378, 112.7957] throttle = 0.2 steer_angle = 12.7566 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.0555968284607 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0026 position = [129.2744, 112.7798] throttle = 0.2 steer_angle = 11.734 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.0887370109558 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0026 position = [129.2744, 112.7798] throttle = 0.2 steer_angle = 11.734 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.11109495162964 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9997 position = [129.3476, 112.7486] throttle = 0.0 steer_angle = 10.9038 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.13312292099 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9955 position = [129.4211, 112.7184] throttle = 0.0 steer_angle = 10.2135 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.15513682365417 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9932 position = [129.4579, 112.7037] throttle = 0.0 steer_angle = 10.2135 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.18999004364014 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9938 position = [129.532, 112.6747] throttle = 0.2 steer_angle = 9.7498 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.2219259738922 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9938 position = [129.532, 112.6747] throttle = 0.2 steer_angle = 9.7498 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.24588704109192 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9956 position = [129.6066, 112.6465] throttle = 0.2 steer_angle = 9.3841 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.2686629295349 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9967 position = [129.6441, 112.6326] throttle = 0.2 steer_angle = 9.2704 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.29159688949585 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9986 position = [129.719, 112.6056] throttle = 0.2 steer_angle = 9.2704 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.3227779865265 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9996 position = [129.7566, 112.5923] throttle = 0.2 steer_angle = 8.6161 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.35596084594727 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9996 position = [129.7566, 112.5923] throttle = 0.2 steer_angle = 8.6161 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.38161087036133 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0016 position = [129.832, 112.5665] throttle = 0.2 steer_angle = 8.6465 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.40456891059875 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.004 position = [129.908, 112.5415] throttle = 0.2 steer_angle = 8.0139 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.42760586738586 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.005 position = [129.9461, 112.5294] throttle = 0.2 steer_angle = 8.0139 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.45722794532776 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0019 position = [130.0224, 112.5055] throttle = 0.0 steer_angle = 7.3672 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.48977184295654 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0019 position = [130.0224, 112.5055] throttle = 0.0 steer_angle = 7.3672 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.51239585876465 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9975 position = [130.0986, 112.4822] throttle = 0.0 steer_angle = 6.7571 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.53535294532776 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.993 position = [130.1748, 112.4594] throttle = 0.0 steer_angle = 6.4849 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.55872797966003 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9907 position = [130.2129, 112.4484] throttle = 0.0 steer_angle = 6.4849 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.58988690376282 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9917 position = [130.2893, 112.4265] throttle = 0.2 steer_angle = 5.6971 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.62287402153015 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9917 position = [130.2893, 112.4265] throttle = 0.2 steer_angle = 5.6971 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.64555501937866 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9929 position = [130.3276, 112.4156] throttle = 0.2 steer_angle = 5.1853 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.66852283477783 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.995 position = [130.4045, 112.3942] throttle = 0.2 steer_angle = 5.0885 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.69394397735596 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9971 position = [130.4815, 112.3734] throttle = 0.2 steer_angle = 5.0885 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.7230930328369 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9995 position = [130.5587, 112.3527] throttle = 0.2 steer_angle = 4.2886 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.75614094734192 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9995 position = [130.5587, 112.3527] throttle = 0.2 steer_angle = 4.2886 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.77885103225708 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0008 position = [130.5973, 112.3425] throttle = 0.2 steer_angle = 3.6034 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.80131196975708 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0031 position = [130.6747, 112.3221] throttle = 0.2 steer_angle = 3.1412 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.82365703582764 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0054 position = [130.7523, 112.302] throttle = 0.2 steer_angle = 3.1412 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.85675501823425 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0044 position = [130.791, 112.292] throttle = 0.0 steer_angle = 2.6574 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.88922691345215 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0044 position = [130.791, 112.292] throttle = 0.0 steer_angle = 2.6574 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.91415882110596 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 2.0001 position = [130.8684, 112.2722] throttle = 0.0 steer_angle = 2.4738 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.93758392333984 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9957 position = [130.9455, 112.2525] throttle = 0.0 steer_angle = 1.7398 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.96082401275635 samples remaining: 6 samples collected: 0
# Current FPS: 38
# dict_keys(['yaw', 'sample_count', 'samples_y', 'steering_angle', 'speed', 'picking_up', 'position', 'image', 'samples_x', 'near_sample', 'pitch', 'throttle', 'roll', 'brake'])
# speed = 1.9936 position = [130.984, 112.2427] throttle = 0.0 steer_angle = 1.7398 near_sample: 0 picking_up: 0 sending pickup: False total time: 131.98882389068604 samples remaining: 6 samples collected: 0
# 127.0.0.1 - - [01/Sep/2018 14:46:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 200 0 132.051761

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Uncomment the next line for use in a Jupyter notebook
#%matplotlib inline
import numpy as np
import cv2 as cv

# Define a function to perform a perspective transform
def perspect_transform(img, src, dst):
           
    M = cv.getPerspectiveTransform(src, dst)
    warped = cv.warpPerspective(img, M, (img.shape[1], img.shape[0]))# keep same size as input image
    
    return warped

def color_thresh(img, rgb_thresh=(160, 160, 160)):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:, :, 0] > rgb_thresh[0]) \
                & (img[:, :, 1] > rgb_thresh[1]) \
                & (img[:, :, 2] > rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    color_select[above_thresh] = 1
    # Return the binary image
    return color_select


# Read in the same sample image as before
img = mpimg.imread('../calibration_images/example_rock2.jpg')


dst_size = 5 
# Set a bottom offset to account for the fact that the bottom of the image 
# is not the position of the rover but a bit in front of it
# this is just a rough guess, feel free to change it!
bottom_offset = 6
src = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
dest = np.float32([[img.shape[1]/2 - dst_size, img.shape[0] - bottom_offset],
                  [img.shape[1]/2 + dst_size, img.shape[0] - bottom_offset],
                  [img.shape[1]/2 + dst_size, img.shape[0] - 2*dst_size - bottom_offset], 
                  [img.shape[1]/2 - dst_size, img.shape[0] - 2*dst_size - bottom_offset],
                                                  ])

# Assume you have already defined perspect_transform() and color_thresh()
warped = perspect_transform(img, src, dest)
colorsel = color_thresh(warped, rgb_thresh=(160, 160, 160))

# Plot the result
plt.imshow(colorsel, cmap='gray')
plt.show()
